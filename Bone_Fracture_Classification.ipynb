# %% [markdown]
# <a href="https://colab.research.google.com/github/akhileshchoudary/bone-fracture-classification/blob/main/Bone_Fracture_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

data_path = '/content/drive/MyDrive/Bone Break Classification'
print("Classes:", os.listdir(data_path))
# Out:
# Classes: ['Pathological fracture', 'Hairline Fracture', 'Longitudinal fracture', 'Comminuted fracture', 'Impacted fracture', 'Avulsion fracture', 'Greenstick fracture', 'Fracture Dislocation', 'Spiral Fracture', 'Oblique fracture']

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

data_path = '/content/drive/MyDrive/Bone Break Classification'
sample_class = 'Avulsion fracture'
img_folder = os.path.join(data_path, sample_class, 'Train')

# Check the first image file in the folder
sample_img = os.path.join(img_folder, os.listdir(img_folder)[0])

# Read and display the image
img = mpimg.imread(sample_img)
plt.imshow(img)
plt.title(f"Sample from {sample_class}")
plt.axis('off')
plt.show()
